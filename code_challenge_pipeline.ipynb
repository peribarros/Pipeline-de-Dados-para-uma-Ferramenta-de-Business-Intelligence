# %%
## Bibliotecas e Banco de Dados ##

import pandas as pd
import sqlalchemy
import psycopg2

# Conexão com o banco de dados NorthWind
engine_northwind = sqlalchemy.create_engine('postgresql+psycopg2://postgres:123456@127.0.0.1:5432/postgres')

# Conexão com o banco de dados final (ElephantSQL:https://www.elephantsql.com / Login: datassauro@gmail.com / Senha: thewindisblowing1!)
engine_elephantsql = sqlalchemy.create_engine('postgresql+psycopg2://dldlrnad:YiE0k9ghZvmNk0ROBQhzH03ElpRJk0SS@kesavan.db.elephantsql.com/dldlrnad')

print('Conectado ao Banco de Dados Northwind e ao Banco de Dados Final')

# %%
############ Parte 1 #############

# módulo da data de hoje - ano/mês/dia
from datetime import date
data_hoje = date.today()

# Salvando as tabelas Northwind nas subpastas local.
categories = pd.read_sql_table('categories',engine_northwind)
categories.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\categories\{}\categories.sql'.format(data_hoje))

customer_customer_demo = pd.read_sql_table('customer_customer_demo',engine_northwind)
customer_customer_demo.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\customer_customer_demo\{}\customer_customer_demo.sql'.format(data_hoje))

customer_demographics = pd.read_sql_table('customer_demographics',engine_northwind)
customer_demographics.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\customer_demographics\{}\customer_demographics.sql'.format(data_hoje))

customers = pd.read_sql_table('customers',engine_northwind)
customers.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\customers\{}\customers.sql'.format(data_hoje))

employee_territories = pd.read_sql_table('employee_territories',engine_northwind)
employee_territories.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\employee_territories\{}\employee_territories.sql'.format(data_hoje))

employees = pd.read_sql_table('employees',engine_northwind)
employees.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\employees\{}\employees.sql'.format(data_hoje))

orders = pd.read_sql_table('orders',engine_northwind)
orders.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\orders\{}\orders.sql'.format(data_hoje))

products = pd.read_sql_table('products',engine_northwind)
products.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\products\{}\products.sql'.format(data_hoje))

region = pd.read_sql_table('region',engine_northwind)
region.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\region\{}\region.sql'.format(data_hoje))

shippers = pd.read_sql_table('shippers',engine_northwind)
shippers.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\shippers\{}\shippers.sql'.format(data_hoje))

suppliers = pd.read_sql_table('suppliers',engine_northwind)
suppliers.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\suppliers\{}\suppliers.sql'.format(data_hoje))

territories = pd.read_sql_table('territories',engine_northwind)
territories.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\territories\{}\territories.sql'.format(data_hoje))

us_states = pd.read_sql_table('us_states',engine_northwind)
us_states.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\us_states\{}\us_states.sql'.format(data_hoje))

# importando order_details.csv do Google Sheets caso precise fazer mudanças constantes; Link da planilha: https://cutt.ly/DWpS1Vs
# e exportando no formato .csv para a subpasta local.

google_sheet_id = '1cMXzIKE1l1PpaQn7OZQDY1Wc4AGpwK17fsw-aM4vewI'
nome_planilha = 'order_details'
URL = 'https://docs.google.com/spreadsheets/d/{0}/gviz/tq?tqx=out:csv&sheet={1}'.format(google_sheet_id, nome_planilha)
order_details = pd.read_csv(URL)
order_details.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\csv\{}\order_details.csv'.format(data_hoje))

# %%
############ Parte 2 #############

# Exportando os arquivos da subpasta local da data de hoje para o banco de dados Postgres no ElephantSQL

subpasta_categories = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\categories\{}\categories.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_categories.to_sql(name = 'categories', con = engine_elephantsql)

subpasta_customer_customer_demo = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\customer_customer_demo\{}\customer_customer_demo.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_customer_customer_demo.to_sql(name = 'customer_customer_demo', con = engine_elephantsql)

subpasta_customer_demographics = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\customer_demographics\{}\customer_demographics.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_customer_demographics.to_sql(name = 'customer_demographics', con = engine_elephantsql)

subpasta_customers = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\customers\{}\customers.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_customers.to_sql(name = 'customers', con = engine_elephantsql)

subpasta_employee_territories = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\employee_territories\{}\employee_territories.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_employee_territories.to_sql(name = 'employee_territories', con = engine_elephantsql)

subpasta_employees = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\employees\{}\employees.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_employees.to_sql(name = 'employees', con = engine_elephantsql)

subpasta_products = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\products\{}\products.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_products.to_sql(name = 'products', con = engine_elephantsql)

subpasta_region = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\region\{}\region.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_region.to_sql(name = 'region', con = engine_elephantsql)

subpasta_shippers = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\shippers\{}\shippers.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_shippers.to_sql(name = 'shippers', con = engine_elephantsql)

subpasta_suppliers = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\suppliers\{}\suppliers.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_suppliers.to_sql(name = 'suppliers', con = engine_elephantsql)

subpasta_territories = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\territories\{}\territories.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_territories.to_sql(name = 'territories', con = engine_elephantsql)

subpasta_us_states = pd.read_csv(r'C:\Users\PC\Documents\desafio_indicium\data\postgres\us_states\{}\us_states.sql'.format(data_hoje)) #subpasta da data de hoje
subpasta_us_states.to_sql(name = 'us_states', con = engine_elephantsql)

############ Consulta Final #############
# Enviando a tabela Consulta final para o banco de dados final (ElephantSQL)
consulta_final = pd.merge(order_details, orders, how = 'inner', on = 'order_id') # tabela order Postgres Northwind e seus detalhes(order_details.cvs)
consulta_final.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\consulta.final.csv') # backup na subpasta local
consulta_final.to_sql(name = 'consulta_final', con = engine_elephantsql) # envio consulta_final.csv para o banco de dados final

# %%
############ Consulta Final #############
# Enviando a tabela Consulta final para o banco de dados final (ElephantSQL)
consulta_final = pd.merge(order_details, orders, how = 'inner', on = 'order_id') # tabela order Postgres Northwind e seus detalhes(order_details.cvs)
consulta_final.to_csv(r'C:\Users\PC\Documents\desafio_indicium\data\consulta.final.csv') # backup na subpasta local
consulta_final.to_sql(name = 'consulta_final', con = engine_elephantsql) # envio consulta_final.csv para o banco de dados final
